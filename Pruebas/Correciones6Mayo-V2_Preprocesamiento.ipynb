# %% [markdown]
# # Preprocesamiento
# ## Recomendaciones/Requerimientos
# * ### Muestra del 20% de los datos
# * ### Considerar únicamente la lista corta de causas de muerte (lc1)
# * ### Eliminar:
# * * ### Defunciones ocurridas fuera de Ecuador
# * * ### Muertes violentas
# * * ### Muertes por COVID-19
# * * ### Causas mal definidas
# * * ### Resto de causas
# * * ### Valores vacíos
# * ### Crear una fecha de almacenamiento que considere año y mes (variable categórica)
# * ### Seleccionar las variables del dataset

# %% [markdown]
# Antes de preprocesar el dataset como tal, se analizan los datos con un software externo y consultando el documento de la metodología del Registro
# Estadístico de Defunciones Generales del INEC, para comprender la información con la que se está trabajando y comenzar a eliminar información innecesaria o inválida
#
# Se comenzará por la lista de consideraciones y eliminaciones del archivo completo

# %%
# %pip install pandas pyreadstat
# Out:
# Requirement already satisfied: pandas in c:\users\crisb\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: pyreadstat in c:\users\crisb\anaconda3\lib\site-packages (1.2.7)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\crisb\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crisb\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crisb\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\crisb\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\crisb\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Bibliotecas
import pandas as pd
import numpy as np

# %% [markdown]
# Se carga y se muestra todo el archivo .sav

# %%
df = pd.read_spss('EDG_1990_2021.sav')
df
# Out:
#           prov_insc  cant_insc  parr_insc  anio_insc    mes_insc  dia_insc  \
# 0              Loja       Loja       Loja     1990.0       Julio       NaN
# 1              Loja       Loja       Loja     1990.0       Junio       NaN
# 2              Loja       Loja       Loja     1990.0  Septiembre       NaN
# 3             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# 4             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# ...             ...        ...        ...        ...         ...       ...
# 1982276      Manabí       Jama       Jama     2021.0   Diciembre      16.0
# 1982277  Chimborazo     Alausí     Alausí     2021.0       Marzo      23.0
# 1982278      El Oro   El Guabo   El Guabo     2021.0   Noviembre      11.0
# 1982279        Loja  Espíndola    Amaluza     2021.0      Agosto      30.0
# 1982280   Pichincha  Rumiñahui  Sangolquí     2021.0  Septiembre      21.0
#
#          fecha_insc         nac_fall               cod_pais    sexo  ...  \
# 0               NaN              NaN                          Mujer  ...
# 1               NaN              NaN                         Hombre  ...
# 2               NaN              NaN                         Hombre  ...
# 3               NaN              NaN                         Hombre  ...
# 4               NaN              NaN                          Mujer  ...
# ...             ...              ...                    ...     ...  ...
# 1982276  2021-12-16  Sin información  Zonas sin especificar  Hombre  ...
# 1982277  2021-03-23      Ecuatoriana                Ecuador  Hombre  ...
# 1982278  2021-11-11      Ecuatoriana                Ecuador  Hombre  ...
# 1982279  2021-08-30      Ecuatoriana                Ecuador   Mujer  ...
# 1982280  2021-09-21      Ecuatoriana                Ecuador   Mujer  ...
#
#          area_fall area_res  \
# 0           Urbana   Urbano
# 1           Urbana   Urbano
# 2           Urbana   Urbano
# 3           Urbana   Urbano
# 4           Urbana   Urbano
# ...            ...      ...
# 1982276     Urbana   Urbano
# 1982277      Rural    Rural
# 1982278     Urbana   Urbano
# 1982279      Rural    Rural
# 1982280      Rural    Rural
#
#                                                     causa3  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 1982276  Y87   Secuelas de lesiones autoinfligidas inte...
# 1982277            Y89   Secuelas de otras causas externas
# 1982278            Y89   Secuelas de otras causas externas
# 1982279            Y89   Secuelas de otras causas externas
# 1982280            Y89   Secuelas de otras causas externas
#
#                                                      causa  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 1982276  Y87   Secuelas de lesiones autoinfligidas inte...
# 1982277            Y89   Secuelas de otras causas externas
# 1982278            Y89   Secuelas de otras causas externas
# 1982279            Y89   Secuelas de otras causas externas
# 1982280            Y89   Secuelas de otras causas externas
#
#                                     causa103  \
# 0                                        999
# 1                                        999
# 2                                        999
# 3                                        999
# 4                                        999
# ...                                      ...
# 1982276  103 Todas las demás causas externas
# 1982277  103 Todas las demás causas externas
# 1982278  103 Todas las demás causas externas
# 1982279  103 Todas las demás causas externas
# 1982280  103 Todas las demás causas externas
#
#                                      causa80  \
# 0                                        999
# 1                                        999
# 2                                        999
# 3                                        999
# 4                                        999
# ...                                      ...
# 1982276  080 Todas las demás causas externas
# 1982277  080 Todas las demás causas externas
# 1982278  080 Todas las demás causas externas
# 1982279  080 Todas las demás causas externas
# 1982280  080 Todas las demás causas externas
#
#                                                   causa67A  \
# 0                                                      999
# 1                                                      999
# 2                                                      999
# 3                                                      999
# 4                                                      999
# ...                                                    ...
# 1982276  060 Causas externas de morbilidad y de mortalidad
# 1982277  060 Causas externas de morbilidad y de mortalidad
# 1982278  060 Causas externas de morbilidad y de mortalidad
# 1982279  060 Causas externas de morbilidad y de mortalidad
# 1982280  060 Causas externas de morbilidad y de mortalidad
#
#                                     causa67B  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 1982276  067 Todas las demás causas externas
# 1982277  067 Todas las demás causas externas
# 1982278  067 Todas las demás causas externas
# 1982279  067 Todas las demás causas externas
# 1982280  067 Todas las demás causas externas
#
#                                                     causa4                 lc1
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
# ...                                                    ...                 ...
# 1982276  Y872  Secuelas de eventos de intención no dete...  88 Resto de causas
# 1982277    Y899  Secuelas de causa externa no especificada  88 Resto de causas
# 1982278    Y899  Secuelas de causa externa no especificada  88 Resto de causas
# 1982279    Y899  Secuelas de causa externa no especificada  88 Resto de causas
# 1982280    Y899  Secuelas de causa externa no especificada  88 Resto de causas
#
# [1982281 rows x 49 columns]

# %% [markdown]
# La primer consideración en la lista del principio es considerar solo la lista lc1, adicionalmente, considerar solo las muertes por causas naturales.
# La lista lc1 se refiere a la **lista reducida de causas de muerte CIE-10**

# %% [markdown]
# Se comenzará eliminando todos los datos que no contengan información alguna en la columna lc1

# %%
#Se crea nuevo dataset para almacenar los preprocesamientos
df_1 = df.dropna(subset=['lc1'])
df_1

#df.dropna(subset=['lc1'])
# Out:
#           prov_insc  cant_insc  parr_insc  anio_insc    mes_insc  dia_insc  \
# 363765       El Oro    Machala    Machala     1997.0       Enero       NaN
# 363766       El Oro    Machala    Machala     1997.0        Mayo       NaN
# 363767       El Oro  Arenillas  Arenillas     1997.0   Noviembre       NaN
# 363768       El Oro   El Guabo   El Guabo     1997.0       Marzo       NaN
# 363769       El Oro   El Guabo   El Guabo     1997.0  Septiembre       NaN
# ...             ...        ...        ...        ...         ...       ...
# 1982276      Manabí       Jama       Jama     2021.0   Diciembre      16.0
# 1982277  Chimborazo     Alausí     Alausí     2021.0       Marzo      23.0
# 1982278      El Oro   El Guabo   El Guabo     2021.0   Noviembre      11.0
# 1982279        Loja  Espíndola    Amaluza     2021.0      Agosto      30.0
# 1982280   Pichincha  Rumiñahui  Sangolquí     2021.0  Septiembre      21.0
#
#          fecha_insc         nac_fall               cod_pais    sexo  ...  \
# 363765          NaN              NaN                         Hombre  ...
# 363766          NaN              NaN                         Hombre  ...
# 363767          NaN              NaN                         Hombre  ...
# 363768          NaN              NaN                          Mujer  ...
# 363769          NaN              NaN                         Hombre  ...
# ...             ...              ...                    ...     ...  ...
# 1982276  2021-12-16  Sin información  Zonas sin especificar  Hombre  ...
# 1982277  2021-03-23      Ecuatoriana                Ecuador  Hombre  ...
# 1982278  2021-11-11      Ecuatoriana                Ecuador  Hombre  ...
# 1982279  2021-08-30      Ecuatoriana                Ecuador   Mujer  ...
# 1982280  2021-09-21      Ecuatoriana                Ecuador   Mujer  ...
#
#          area_fall area_res  \
# 363765      Urbana   Urbano
# 363766      Urbana   Urbano
# 363767      Urbana   Urbano
# 363768      Urbana   Urbano
# 363769      Urbana   Urbano
# ...            ...      ...
# 1982276     Urbana   Urbano
# 1982277      Rural    Rural
# 1982278     Urbana   Urbano
# 1982279      Rural    Rural
# 1982280      Rural    Rural
#
#                                                     causa3  \
# 363765   X95   Agresión con disparo de otras armas de f...
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363769   G08   Flebitis y tromboflebitis intracraneal e...
# ...                                                    ...
# 1982276  Y87   Secuelas de lesiones autoinfligidas inte...
# 1982277            Y89   Secuelas de otras causas externas
# 1982278            Y89   Secuelas de otras causas externas
# 1982279            Y89   Secuelas de otras causas externas
# 1982280            Y89   Secuelas de otras causas externas
#
#                                                      causa  \
# 363765   X95   Agresión con disparo de otras armas de f...
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363769   G08   Flebitis y tromboflebitis intracraneal e...
# ...                                                    ...
# 1982276  Y87   Secuelas de lesiones autoinfligidas inte...
# 1982277            Y89   Secuelas de otras causas externas
# 1982278            Y89   Secuelas de otras causas externas
# 1982279            Y89   Secuelas de otras causas externas
# 1982280            Y89   Secuelas de otras causas externas
#
#                                                causa103  \
# 363765                                   102 Agresiones
# 363766                   029 Tumor maligno del estomago
# 363767     101 Lesiones autoinfligidas intencionalmente
# 363768                                   059 Meningitis
# 363769   061 Resto de enfermedades del sistema nervioso
# ...                                                 ...
# 1982276             103 Todas las demás causas externas
# 1982277             103 Todas las demás causas externas
# 1982278             103 Todas las demás causas externas
# 1982279             103 Todas las demás causas externas
# 1982280             103 Todas las demás causas externas
#
#                                               causa80  \
# 363765                                 079 Agresiones
# 363766                 027 Tumor maligno del estomago
# 363767   078 Lesiones autoinfligidas intencionalmente
# 363768                                 049 Meningitis
# 363769               072 Todas las demas enfermedades
# ...                                               ...
# 1982276           080 Todas las demás causas externas
# 1982277           080 Todas las demás causas externas
# 1982278           080 Todas las demás causas externas
# 1982279           080 Todas las demás causas externas
# 1982280           080 Todas las demás causas externas
#
#                                                   causa67A  \
# 363765   060 Causas externas de morbilidad y de mortalidad
# 363766                            016 Tumores [neoplasias]
# 363767   060 Causas externas de morbilidad y de mortalidad
# 363768               026 Enfermedades del sistema nervioso
# 363769               026 Enfermedades del sistema nervioso
# ...                                                    ...
# 1982276  060 Causas externas de morbilidad y de mortalidad
# 1982277  060 Causas externas de morbilidad y de mortalidad
# 1982278  060 Causas externas de morbilidad y de mortalidad
# 1982279  060 Causas externas de morbilidad y de mortalidad
# 1982280  060 Causas externas de morbilidad y de mortalidad
#
#                                                causa67B  \
# 363765                                   066 Agresiones
# 363766                    018 Resto de tumores malignos
# 363767              067 Todas las demás causas externas
# 363768                                   027 Meningitis
# 363769   028 Resto de enfermedades del sistema nervioso
# ...                                                 ...
# 1982276             067 Todas las demás causas externas
# 1982277             067 Todas las demás causas externas
# 1982278             067 Todas las demás causas externas
# 1982279             067 Todas las demás causas externas
# 1982280             067 Todas las demás causas externas
#
#                                                     causa4  \
# 363765   X950  Agresión con disparo de otras armas de f...
# 363766   C169  Tumor maligno del estómago, parte no esp...
# 363767   X749  Lesión autoinfligida intencionalmente po...
# 363768                   G039  Meningitis, no especificada
# 363769   G08   Flebitis y tromboflebitis intracraneal e...
# ...                                                    ...
# 1982276  Y872  Secuelas de eventos de intención no dete...
# 1982277    Y899  Secuelas de causa externa no especificada
# 1982278    Y899  Secuelas de causa externa no especificada
# 1982279    Y899  Secuelas de causa externa no especificada
# 1982280    Y899  Secuelas de causa externa no especificada
#
#                                                        lc1
# 363765                          64 Agresiones (Homicidios)
# 363766                    9 Neoplasia maligna del estómago
# 363767   63 Lesiones autoinflingidas intencionalmente (...
# 363768                                        5 Meningitis
# 363769                                  88 Resto de causas
# ...                                                    ...
# 1982276                                 88 Resto de causas
# 1982277                                 88 Resto de causas
# 1982278                                 88 Resto de causas
# 1982279                                 88 Resto de causas
# 1982280                                 88 Resto de causas
#
# [1618516 rows x 49 columns]

# %% [markdown]
# Las eliminaciones de muertes violentas, por COVID-19, por causas mal definidas y por el resto de causas pueden eliminarse al mismo tiempo

# %% [markdown]
# Sus valores lc1 son 64, 66 y 67 (COVID), 99 y 88 respectivamente

# %%
lc1_del = ['64 Agresiones (Homicidios)', 'COVID-19, virus identificado', 'COVID-19, virus no identificado', '99 Causas mal definidas', '88 Resto de causas'] #Lista de valores lc1 a eliminar
df_1 = df_1[~df_1['lc1'].isin(lc1_del)]
df_1
# Out:
#          prov_insc                        cant_insc   parr_insc  anio_insc  \
# 363766      El Oro                          Machala     Machala     1997.0
# 363767      El Oro                        Arenillas   Arenillas     1997.0
# 363768      El Oro                         El Guabo    El Guabo     1997.0
# 363770      El Oro                         El Guabo    El Guabo     1997.0
# 363771      El Oro                           Pasaje      Pasaje     1997.0
# ...            ...                              ...         ...        ...
# 1982230     Guayas                        Guayaquil  Rocafuerte     2021.0
# 1982231  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982232  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982233  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982234  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
#
#            mes_insc  dia_insc  fecha_insc         nac_fall  \
# 363766         Mayo       NaN         NaN              NaN
# 363767    Noviembre       NaN         NaN              NaN
# 363768        Marzo       NaN         NaN              NaN
# 363770    Diciembre       NaN         NaN              NaN
# 363771    Noviembre       NaN         NaN              NaN
# ...             ...       ...         ...              ...
# 1982230     Octubre      20.0  2021-10-20  Sin información
# 1982231       Abril       6.0  2021-04-06       Extranjero
# 1982232        Mayo      18.0  2021-05-18  Sin información
# 1982233        Mayo      14.0  2021-05-14  Sin información
# 1982234  Septiembre      29.0  2021-09-29  Sin información
#
#                       cod_pais    sexo  ...  area_fall area_res  \
# 363766                          Hombre  ...     Urbana   Urbano
# 363767                          Hombre  ...     Urbana   Urbano
# 363768                           Mujer  ...     Urbana   Urbano
# 363770                          Hombre  ...     Urbana   Urbano
# 363771                          Hombre  ...     Urbana   Urbano
# ...                        ...     ...  ...        ...      ...
# 1982230  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982231  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982232  Zonas sin especificar  Hombre  ...      Rural   Urbano
# 1982233  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982234  Zonas sin especificar   Mujer  ...      Rural   Urbano
#
#                                                     causa3  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                                      causa  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                              causa103  \
# 363766                 029 Tumor maligno del estomago
# 363767   101 Lesiones autoinfligidas intencionalmente
# 363768                                 059 Meningitis
# 363770                  005 Tuberculosis respiratoria
# 363771       098 Ahogamiento y sumersión accidentales
# ...                                               ...
# 1982230           103 Todas las demás causas externas
# 1982231           103 Todas las demás causas externas
# 1982232           103 Todas las demás causas externas
# 1982233           103 Todas las demás causas externas
# 1982234           103 Todas las demás causas externas
#
#                                               causa80  \
# 363766                 027 Tumor maligno del estomago
# 363767   078 Lesiones autoinfligidas intencionalmente
# 363768                                 049 Meningitis
# 363770                 004 tuberculosis respiratorias
# 363771       075 Ahogamiento y sumersion accidentales
# ...                                               ...
# 1982230           080 Todas las demás causas externas
# 1982231           080 Todas las demás causas externas
# 1982232           080 Todas las demás causas externas
# 1982233           080 Todas las demás causas externas
# 1982234           080 Todas las demás causas externas
#
#                                                   causa67A  \
# 363766                            016 Tumores [neoplasias]
# 363767   060 Causas externas de morbilidad y de mortalidad
# 363768               026 Enfermedades del sistema nervioso
# 363770   001 Ciertas enfermedades infecciosas y parasit...
# 363771   060 Causas externas de morbilidad y de mortalidad
# ...                                                    ...
# 1982230  060 Causas externas de morbilidad y de mortalidad
# 1982231  060 Causas externas de morbilidad y de mortalidad
# 1982232  060 Causas externas de morbilidad y de mortalidad
# 1982233  060 Causas externas de morbilidad y de mortalidad
# 1982234  060 Causas externas de morbilidad y de mortalidad
#
#                                          causa67B  \
# 363766              018 Resto de tumores malignos
# 363767        067 Todas las demás causas externas
# 363768                             027 Meningitis
# 363770                           004 Tuberculosis
# 363771   062 Ahogamiento y sumersión accidentales
# ...                                           ...
# 1982230       067 Todas las demás causas externas
# 1982231       067 Todas las demás causas externas
# 1982232       067 Todas las demás causas externas
# 1982233       067 Todas las demás causas externas
# 1982234       067 Todas las demás causas externas
#
#                                                     causa4  \
# 363766   C169  Tumor maligno del estómago, parte no esp...
# 363767   X749  Lesión autoinfligida intencionalmente po...
# 363768                   G039  Meningitis, no especificada
# 363770   A162  Tuberculosis de pulmón, sin mención de c...
# 363771   W698  Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y344  Evento no especificado, de intención no ...
# 1982231  Y349  Evento no especificado, de intención no ...
# 1982232  Y349  Evento no especificado, de intención no ...
# 1982233  Y349  Evento no especificado, de intención no ...
# 1982234  Y349  Evento no especificado, de intención no ...
#
#                                                        lc1
# 363766                    9 Neoplasia maligna del estómago
# 363767   63 Lesiones autoinflingidas intencionalmente (...
# 363768                                        5 Meningitis
# 363770                                      2 Tuberculosis
# 363771             60 Ahogamiento y sumersión accidentales
# ...                                                    ...
# 1982230             65 Eventos de intención no determinada
# 1982231             65 Eventos de intención no determinada
# 1982232             65 Eventos de intención no determinada
# 1982233             65 Eventos de intención no determinada
# 1982234             65 Eventos de intención no determinada
#
# [1255110 rows x 49 columns]

# %% [markdown]
# La columna **prov_fall** será útil para eliminar las filas de defunciones ocurridas fuera de Ecuador, se eliminarán las filas que tengan a prov_fall vacía entendiéndose como que fallecieron en territorio externo a cualquier provincia (Ecuador)

# %%
df_1 = df_1.dropna(subset=['prov_fall']) #Eliminación de valores nulos
df_1
# Out:
#          prov_insc                        cant_insc   parr_insc  anio_insc  \
# 363766      El Oro                          Machala     Machala     1997.0
# 363767      El Oro                        Arenillas   Arenillas     1997.0
# 363768      El Oro                         El Guabo    El Guabo     1997.0
# 363770      El Oro                         El Guabo    El Guabo     1997.0
# 363771      El Oro                           Pasaje      Pasaje     1997.0
# ...            ...                              ...         ...        ...
# 1982230     Guayas                        Guayaquil  Rocafuerte     2021.0
# 1982231  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982232  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982233  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
# 1982234  Pichincha  Distrito Metropolitano de Quito    Iñaquito     2021.0
#
#            mes_insc  dia_insc  fecha_insc         nac_fall  \
# 363766         Mayo       NaN         NaN              NaN
# 363767    Noviembre       NaN         NaN              NaN
# 363768        Marzo       NaN         NaN              NaN
# 363770    Diciembre       NaN         NaN              NaN
# 363771    Noviembre       NaN         NaN              NaN
# ...             ...       ...         ...              ...
# 1982230     Octubre      20.0  2021-10-20  Sin información
# 1982231       Abril       6.0  2021-04-06       Extranjero
# 1982232        Mayo      18.0  2021-05-18  Sin información
# 1982233        Mayo      14.0  2021-05-14  Sin información
# 1982234  Septiembre      29.0  2021-09-29  Sin información
#
#                       cod_pais    sexo  ...  area_fall area_res  \
# 363766                          Hombre  ...     Urbana   Urbano
# 363767                          Hombre  ...     Urbana   Urbano
# 363768                           Mujer  ...     Urbana   Urbano
# 363770                          Hombre  ...     Urbana   Urbano
# 363771                          Hombre  ...     Urbana   Urbano
# ...                        ...     ...  ...        ...      ...
# 1982230  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982231  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982232  Zonas sin especificar  Hombre  ...      Rural   Urbano
# 1982233  Zonas sin especificar  Hombre  ...     Urbana   Urbano
# 1982234  Zonas sin especificar   Mujer  ...      Rural   Urbano
#
#                                                     causa3  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                                      causa  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                              causa103  \
# 363766                 029 Tumor maligno del estomago
# 363767   101 Lesiones autoinfligidas intencionalmente
# 363768                                 059 Meningitis
# 363770                  005 Tuberculosis respiratoria
# 363771       098 Ahogamiento y sumersión accidentales
# ...                                               ...
# 1982230           103 Todas las demás causas externas
# 1982231           103 Todas las demás causas externas
# 1982232           103 Todas las demás causas externas
# 1982233           103 Todas las demás causas externas
# 1982234           103 Todas las demás causas externas
#
#                                               causa80  \
# 363766                 027 Tumor maligno del estomago
# 363767   078 Lesiones autoinfligidas intencionalmente
# 363768                                 049 Meningitis
# 363770                 004 tuberculosis respiratorias
# 363771       075 Ahogamiento y sumersion accidentales
# ...                                               ...
# 1982230           080 Todas las demás causas externas
# 1982231           080 Todas las demás causas externas
# 1982232           080 Todas las demás causas externas
# 1982233           080 Todas las demás causas externas
# 1982234           080 Todas las demás causas externas
#
#                                                   causa67A  \
# 363766                            016 Tumores [neoplasias]
# 363767   060 Causas externas de morbilidad y de mortalidad
# 363768               026 Enfermedades del sistema nervioso
# 363770   001 Ciertas enfermedades infecciosas y parasit...
# 363771   060 Causas externas de morbilidad y de mortalidad
# ...                                                    ...
# 1982230  060 Causas externas de morbilidad y de mortalidad
# 1982231  060 Causas externas de morbilidad y de mortalidad
# 1982232  060 Causas externas de morbilidad y de mortalidad
# 1982233  060 Causas externas de morbilidad y de mortalidad
# 1982234  060 Causas externas de morbilidad y de mortalidad
#
#                                          causa67B  \
# 363766              018 Resto de tumores malignos
# 363767        067 Todas las demás causas externas
# 363768                             027 Meningitis
# 363770                           004 Tuberculosis
# 363771   062 Ahogamiento y sumersión accidentales
# ...                                           ...
# 1982230       067 Todas las demás causas externas
# 1982231       067 Todas las demás causas externas
# 1982232       067 Todas las demás causas externas
# 1982233       067 Todas las demás causas externas
# 1982234       067 Todas las demás causas externas
#
#                                                     causa4  \
# 363766   C169  Tumor maligno del estómago, parte no esp...
# 363767   X749  Lesión autoinfligida intencionalmente po...
# 363768                   G039  Meningitis, no especificada
# 363770   A162  Tuberculosis de pulmón, sin mención de c...
# 363771   W698  Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y344  Evento no especificado, de intención no ...
# 1982231  Y349  Evento no especificado, de intención no ...
# 1982232  Y349  Evento no especificado, de intención no ...
# 1982233  Y349  Evento no especificado, de intención no ...
# 1982234  Y349  Evento no especificado, de intención no ...
#
#                                                        lc1
# 363766                    9 Neoplasia maligna del estómago
# 363767   63 Lesiones autoinflingidas intencionalmente (...
# 363768                                        5 Meningitis
# 363770                                      2 Tuberculosis
# 363771             60 Ahogamiento y sumersión accidentales
# ...                                                    ...
# 1982230             65 Eventos de intención no determinada
# 1982231             65 Eventos de intención no determinada
# 1982232             65 Eventos de intención no determinada
# 1982233             65 Eventos de intención no determinada
# 1982234             65 Eventos de intención no determinada
#
# [1255110 rows x 49 columns]

# %% [markdown]
# Limpiamos el dataset de valores NaN

# %%
# Convertir todas las columnas categóricas a tipo categórico si no lo están
categorical_columns = df_1.select_dtypes(include=['category']).columns
df_1[categorical_columns] = df_1[categorical_columns].astype('category')

# Añadir la categoría 'Desconocido' a cada columna categórica si aún no está presente
for col in categorical_columns:
    if 'Desconocido' not in df_1[col].cat.categories:
        df_1[col] = df_1[col].cat.add_categories('Desconocido')

# Reemplazar todos los valores NaN en el DataFrame df_1 con la cadena 'Desconocido'
df_1_clean = df_1.fillna('Desconocido')
# Convertir todas las columnas a tipo de datos cadena
df_1_clean = df_1_clean.astype(str)

# %%
df_1_clean
# Out:
#          prov_insc                        cant_insc   parr_insc anio_insc  \
# 363766      El Oro                          Machala     Machala    1997.0
# 363767      El Oro                        Arenillas   Arenillas    1997.0
# 363768      El Oro                         El Guabo    El Guabo    1997.0
# 363770      El Oro                         El Guabo    El Guabo    1997.0
# 363771      El Oro                           Pasaje      Pasaje    1997.0
# ...            ...                              ...         ...       ...
# 1982230     Guayas                        Guayaquil  Rocafuerte    2021.0
# 1982231  Pichincha  Distrito Metropolitano de Quito    Iñaquito    2021.0
# 1982232  Pichincha  Distrito Metropolitano de Quito    Iñaquito    2021.0
# 1982233  Pichincha  Distrito Metropolitano de Quito    Iñaquito    2021.0
# 1982234  Pichincha  Distrito Metropolitano de Quito    Iñaquito    2021.0
#
#            mes_insc     dia_insc   fecha_insc         nac_fall  \
# 363766         Mayo  Desconocido  Desconocido      Desconocido
# 363767    Noviembre  Desconocido  Desconocido      Desconocido
# 363768        Marzo  Desconocido  Desconocido      Desconocido
# 363770    Diciembre  Desconocido  Desconocido      Desconocido
# 363771    Noviembre  Desconocido  Desconocido      Desconocido
# ...             ...          ...          ...              ...
# 1982230     Octubre         20.0   2021-10-20  Sin información
# 1982231       Abril          6.0   2021-04-06       Extranjero
# 1982232        Mayo         18.0   2021-05-18  Sin información
# 1982233        Mayo         14.0   2021-05-14  Sin información
# 1982234  Septiembre         29.0   2021-09-29  Sin información
#
#                       cod_pais    sexo  ... area_fall area_res  \
# 363766                          Hombre  ...    Urbana   Urbano
# 363767                          Hombre  ...    Urbana   Urbano
# 363768                           Mujer  ...    Urbana   Urbano
# 363770                          Hombre  ...    Urbana   Urbano
# 363771                          Hombre  ...    Urbana   Urbano
# ...                        ...     ...  ...       ...      ...
# 1982230  Zonas sin especificar  Hombre  ...    Urbana   Urbano
# 1982231  Zonas sin especificar  Hombre  ...    Urbana   Urbano
# 1982232  Zonas sin especificar  Hombre  ...     Rural   Urbano
# 1982233  Zonas sin especificar  Hombre  ...    Urbana   Urbano
# 1982234  Zonas sin especificar   Mujer  ...     Rural   Urbano
#
#                                                     causa3  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                                      causa  \
# 363766                    C16   Tumor maligno del estómago
# 363767   X74   Lesión autoinfligida intencionalmente po...
# 363768   G03   Meningitis debida a otras causas y a las...
# 363770   A16   Tuberculosis respiratoria, no confirmada...
# 363771   W69   Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y34   Evento no especificado, de intención no ...
# 1982231  Y34   Evento no especificado, de intención no ...
# 1982232  Y34   Evento no especificado, de intención no ...
# 1982233  Y34   Evento no especificado, de intención no ...
# 1982234  Y34   Evento no especificado, de intención no ...
#
#                                              causa103  \
# 363766                 029 Tumor maligno del estomago
# 363767   101 Lesiones autoinfligidas intencionalmente
# 363768                                 059 Meningitis
# 363770                  005 Tuberculosis respiratoria
# 363771       098 Ahogamiento y sumersión accidentales
# ...                                               ...
# 1982230           103 Todas las demás causas externas
# 1982231           103 Todas las demás causas externas
# 1982232           103 Todas las demás causas externas
# 1982233           103 Todas las demás causas externas
# 1982234           103 Todas las demás causas externas
#
#                                               causa80  \
# 363766                 027 Tumor maligno del estomago
# 363767   078 Lesiones autoinfligidas intencionalmente
# 363768                                 049 Meningitis
# 363770                 004 tuberculosis respiratorias
# 363771       075 Ahogamiento y sumersion accidentales
# ...                                               ...
# 1982230           080 Todas las demás causas externas
# 1982231           080 Todas las demás causas externas
# 1982232           080 Todas las demás causas externas
# 1982233           080 Todas las demás causas externas
# 1982234           080 Todas las demás causas externas
#
#                                                   causa67A  \
# 363766                            016 Tumores [neoplasias]
# 363767   060 Causas externas de morbilidad y de mortalidad
# 363768               026 Enfermedades del sistema nervioso
# 363770   001 Ciertas enfermedades infecciosas y parasit...
# 363771   060 Causas externas de morbilidad y de mortalidad
# ...                                                    ...
# 1982230  060 Causas externas de morbilidad y de mortalidad
# 1982231  060 Causas externas de morbilidad y de mortalidad
# 1982232  060 Causas externas de morbilidad y de mortalidad
# 1982233  060 Causas externas de morbilidad y de mortalidad
# 1982234  060 Causas externas de morbilidad y de mortalidad
#
#                                          causa67B  \
# 363766              018 Resto de tumores malignos
# 363767        067 Todas las demás causas externas
# 363768                             027 Meningitis
# 363770                           004 Tuberculosis
# 363771   062 Ahogamiento y sumersión accidentales
# ...                                           ...
# 1982230       067 Todas las demás causas externas
# 1982231       067 Todas las demás causas externas
# 1982232       067 Todas las demás causas externas
# 1982233       067 Todas las demás causas externas
# 1982234       067 Todas las demás causas externas
#
#                                                     causa4  \
# 363766   C169  Tumor maligno del estómago, parte no esp...
# 363767   X749  Lesión autoinfligida intencionalmente po...
# 363768                   G039  Meningitis, no especificada
# 363770   A162  Tuberculosis de pulmón, sin mención de c...
# 363771   W698  Ahogamiento y sumersión mientras se está...
# ...                                                    ...
# 1982230  Y344  Evento no especificado, de intención no ...
# 1982231  Y349  Evento no especificado, de intención no ...
# 1982232  Y349  Evento no especificado, de intención no ...
# 1982233  Y349  Evento no especificado, de intención no ...
# 1982234  Y349  Evento no especificado, de intención no ...
#
#                                                        lc1
# 363766                    9 Neoplasia maligna del estómago
# 363767   63 Lesiones autoinflingidas intencionalmente (...
# 363768                                        5 Meningitis
# 363770                                      2 Tuberculosis
# 363771             60 Ahogamiento y sumersión accidentales
# ...                                                    ...
# 1982230             65 Eventos de intención no determinada
# 1982231             65 Eventos de intención no determinada
# 1982232             65 Eventos de intención no determinada
# 1982233             65 Eventos de intención no determinada
# 1982234             65 Eventos de intención no determinada
#
# [1255110 rows x 49 columns]

# %% [markdown]
# Generamos el DF Final a utilizar en este caso

# %%
# Seleccionar las columnas especificadas
columns_to_keep = ['sexo', 'anio_fall', 'mes_fall', 'edad', 'lugar_ocur', 'prov_fall', 'area_fall']
df_selected = df_1_clean[columns_to_keep]

# Obtener el 20% de los datos aleatorios
df_Final = df_selected.sample(frac=0.2, random_state=4)

# Mostrar las dimensiones del nuevo DataFrame
print("Dimensiones del nuevo DataFrame:", df_Final.shape)

df_Final
# Out:
# Dimensiones del nuevo DataFrame: (251022, 7)
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall
# 793619                        Pichincha     Rural
# 366899                          Bolívar    Urbana
# 689408                        Pichincha    Urbana
# 474680                           Guayas    Urbana
# 944418                           Guayas    Urbana
# ...                                 ...       ...
# 1681168  Santo Domingo de los Tsachilas    Urbana
# 1138052                          Manabí    Urbana
# 1647239                          Guayas    Urbana
# 1711899                          Guayas    Urbana
# 1956942                          Carchi    Urbana
#
# [251022 rows x 7 columns]

# %% [markdown]
# Este dataframe es mucho más manejable para entornos locales y para ahorrar tiempo con el archivo completo en Colab

# %% [markdown]
# # Algoritmos del codo

# %% [markdown]
# Para comenzar el clustering, se debe definir los nodos para agrupar todos los datos, la primera apoximación se va a realizar con la técnica gráfica del codo para obtener K

# %%
# %pip install kmodes
# Out:
# Requirement already satisfied: kmodes in c:\users\crisb\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\crisb\anaconda3\lib\site-packages (from kmodes) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\crisb\anaconda3\lib\site-packages (from kmodes) (1.2.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\crisb\anaconda3\lib\site-packages (from kmodes) (1.11.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\crisb\anaconda3\lib\site-packages (from kmodes) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\crisb\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from kmodes.kmodes import KModes
# Determinamos el valor óptimo de K

cost_red = []
K_red = range(1,10)
for num_clusters in list(K_red):
  kmode_red = KModes(n_clusters=num_clusters) # Usaremos los hiperparámetros pre-establecidos
  kmode_red.fit_predict(df_Final)
  cost_red.append(kmode_red.cost_)

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\crisb\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\crisb\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\crisb\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.grid('True')
plt.plot(K_red, cost_red, 'bx-')
plt.xlabel('No. of Clusters k')
plt.ylabel('Cost')
plt.title('Elbow Method for Optimal K in K-Modes')
plt.show()

# %% [markdown]
# Hay posibles codos en K = 2 y K = 3

# %% [markdown]
# Mediante Average Silhouette Score podemos saber cuál K es mejor

# %% [markdown]
# Primero, se construirá el modelo con 2 clusters

# %%
n_clusters = 2
km = KModes(n_clusters=n_clusters, init='Huang', n_init=5, n_jobs=-1, verbose=1)
clusters_2 = km.fit_predict(df_Final)
clusters_2
# Out:
# Best run was number 4
# array([1, 0, 0, ..., 0, 0, 0], dtype=uint16)

# %%
# Insertemos las etiquetas en nuestro dataset.
df_FCluster2 = df_Final.copy()
df_FCluster2.insert(7,"cluster_labels", clusters_2)
df_FCluster2
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               1
# 366899                          Bolívar    Urbana               0
# 689408                        Pichincha    Urbana               0
# 474680                           Guayas    Urbana               0
# 944418                           Guayas    Urbana               0
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               0
# 1138052                          Manabí    Urbana               0
# 1647239                          Guayas    Urbana               0
# 1711899                          Guayas    Urbana               0
# 1956942                          Carchi    Urbana               0
#
# [251022 rows x 8 columns]

# %%
# %pip install gower
# Out:
# Requirement already satisfied: gower in c:\users\crisb\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: numpy in c:\users\crisb\anaconda3\lib\site-packages (from gower) (1.26.4)
# Requirement already satisfied: scipy in c:\users\crisb\anaconda3\lib\site-packages (from gower) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Se necesita sacar una muestra del dataframe preprocesado, de lo contrario la memoria RAM será insuficiente hasta para entornos de ejecución locales

# %%
import gower
from sklearn.metrics import silhouette_score

#Muestra
df_str = df_FCluster2.sample(n=5000, random_state=1)

# %%
# Calcular la matriz de distancias de Gower
gower_distances = gower.gower_matrix(df_str.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower = silhouette_score(gower_distances, df_str['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 2:", silhouette_avg_gower)
# Out:
# Average Categorical Silhouette Score con K = 2: 0.108716354

# %% [markdown]
# Con K = 3

# %%
n_clusters = 3
km = KModes(n_clusters=n_clusters, init='Huang', n_init=5, n_jobs=-1,verbose=1)
clusters_3 = km.fit_predict(df_Final)
clusters_3
# Out:
# Best run was number 3
# array([1, 0, 0, ..., 1, 0, 0], dtype=uint16)

# %%
# Insertemos las etiquetas en nuestro dataset original.
df_FCluster3 = df_Final.copy()
df_FCluster3.insert(7,"cluster_labels", clusters_3)
df_FCluster3
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               1
# 366899                          Bolívar    Urbana               0
# 689408                        Pichincha    Urbana               0
# 474680                           Guayas    Urbana               0
# 944418                           Guayas    Urbana               0
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               0
# 1138052                          Manabí    Urbana               0
# 1647239                          Guayas    Urbana               1
# 1711899                          Guayas    Urbana               0
# 1956942                          Carchi    Urbana               0
#
# [251022 rows x 8 columns]

# %%
#Muestra de nuevo
df_str = df_FCluster3.sample(n=5000, random_state=1)

# %%
import gower
from sklearn.metrics import silhouette_score

# Luego calcular la matriz de distancias de Gower como antes
gower_distances = gower.gower_matrix(df_str.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower = silhouette_score(gower_distances, df_str['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 3:", silhouette_avg_gower) 

#Probablemente el print dirá k = 2, ya se corrigió pero no se ejecutó de nuevo por cuestión de tiempo
# Out:
# Average Categorical Silhouette Score con K = 3: 0.08829136

# %% [markdown]
# El cluster con K = 2 parece la mejor opción, a pesar de que el número cercano a cero indicará que habrá superposición entre los clusters

# %% [markdown]
# ## Visualización de los clusters

# %% [markdown]
# Antes de visualizar nada, hay que convertir los valores no categóricos del dataframe a valores dummy

# %%
df_categorical = pd.get_dummies(df_Final)
df_categorical
# Out:
#          sexo_Hombre  sexo_Mujer  anio_fall_1997.0  anio_fall_1998.0  \
# 793619         False        True             False             False
# 366899          True       False              True             False
# 689408          True       False             False             False
# 474680          True       False             False             False
# 944418          True       False             False             False
# ...              ...         ...               ...               ...
# 1681168         True       False             False             False
# 1138052         True       False             False             False
# 1647239        False        True             False             False
# 1711899         True       False             False             False
# 1956942         True       False             False             False
#
#          anio_fall_1999.0  anio_fall_2000.0  anio_fall_2001.0  \
# 793619              False             False             False
# 366899              False             False             False
# 689408              False             False             False
# 474680               True             False             False
# 944418              False             False             False
# ...                   ...               ...               ...
# 1681168             False             False             False
# 1138052             False             False             False
# 1647239             False             False             False
# 1711899             False             False             False
# 1956942             False             False             False
#
#          anio_fall_2002.0  anio_fall_2003.0  anio_fall_2004.0  ...  \
# 793619              False             False              True  ...
# 366899              False             False             False  ...
# 689408               True             False             False  ...
# 474680              False             False             False  ...
# 944418              False             False             False  ...
# ...                   ...               ...               ...  ...
# 1681168             False             False             False  ...
# 1138052             False             False             False  ...
# 1647239             False             False             False  ...
# 1711899             False             False             False  ...
# 1956942             False             False             False  ...
#
#          prov_fall_Orellana  prov_fall_Pastaza  prov_fall_Pichincha  \
# 793619                False              False                 True
# 366899                False              False                False
# 689408                False              False                 True
# 474680                False              False                False
# 944418                False              False                False
# ...                     ...                ...                  ...
# 1681168               False              False                False
# 1138052               False              False                False
# 1647239               False              False                False
# 1711899               False              False                False
# 1956942               False              False                False
#
#          prov_fall_Santa Elena  prov_fall_Santo Domingo de los Tsachilas  \
# 793619                   False                                     False
# 366899                   False                                     False
# 689408                   False                                     False
# 474680                   False                                     False
# 944418                   False                                     False
# ...                        ...                                       ...
# 1681168                  False                                      True
# 1138052                  False                                     False
# 1647239                  False                                     False
# 1711899                  False                                     False
# 1956942                  False                                     False
#
#          prov_fall_Sucumbíos  prov_fall_Tungurahua  \
# 793619                 False                 False
# 366899                 False                 False
# 689408                 False                 False
# 474680                 False                 False
# 944418                 False                 False
# ...                      ...                   ...
# 1681168                False                 False
# 1138052                False                 False
# 1647239                False                 False
# 1711899                False                 False
# 1956942                False                 False
#
#          prov_fall_Zamora Chinchipe  area_fall_Rural  area_fall_Urbana
# 793619                        False             True             False
# 366899                        False            False              True
# 689408                        False            False              True
# 474680                        False            False              True
# 944418                        False            False              True
# ...                             ...              ...               ...
# 1681168                       False            False              True
# 1138052                       False            False              True
# 1647239                       False            False              True
# 1711899                       False            False              True
# 1956942                       False            False              True
#
# [251022 rows x 194 columns]

# %%
# Reducción de la dimensionalidad
# Instalamaos MCA
# %pip install prince
# Out:
# Requirement already satisfied: prince in c:\users\crisb\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: altair<6.0.0,>=4.2.2 in c:\users\crisb\anaconda3\lib\site-packages (from prince) (5.0.1)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in c:\users\crisb\anaconda3\lib\site-packages (from prince) (2.1.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in c:\users\crisb\anaconda3\lib\site-packages (from prince) (1.2.2)
# Requirement already satisfied: jinja2 in c:\users\crisb\anaconda3\lib\site-packages (from altair<6.0.0,>=4.2.2->prince) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\crisb\anaconda3\lib\site-packages (from altair<6.0.0,>=4.2.2->prince) (4.19.2)
# Requirement already satisfied: numpy in c:\users\crisb\anaconda3\lib\site-packages (from altair<6.0.0,>=4.2.2->prince) (1.26.4)
# Requirement already satisfied: toolz in c:\users\crisb\anaconda3\lib\site-packages (from altair<6.0.0,>=4.2.2->prince) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crisb\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.4.1->prince) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crisb\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.4.1->prince) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\crisb\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.4.1->prince) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\crisb\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\crisb\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\crisb\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (2.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\crisb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\crisb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\crisb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\crisb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (0.10.6)
# Requirement already satisfied: six>=1.5 in c:\users\crisb\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.4.1->prince) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\crisb\anaconda3\lib\site-packages (from jinja2->altair<6.0.0,>=4.2.2->prince) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos la libraría Prince que contiene MCA
import prince
# Indicamos el número de componentes que requerimos, que en este caso es dos.
mca = prince.MCA(n_components=2)
# Ajustamos MCA a nuestros datos
mca = mca.fit(df_categorical)
mca
# Transforme el conjunto de datos (esto le dará las coordenadas de cada muestra en los nuevos ejes)
mca_coordinates = mca.transform(df_categorical)
mca_coordinates
# Out:
#                 0         1
# 793619   0.259742 -0.069923
# 366899   0.035148  0.111118
# 689408  -0.001708  0.084789
# 474680  -0.049146  0.055196
# 944418  -0.042757  0.063742
# ...           ...       ...
# 1681168 -0.100004  0.077715
# 1138052 -0.064292  0.175291
# 1647239 -0.114174 -0.144791
# 1711899 -0.015799  0.029335
# 1956942 -0.069102  0.108258
#
# [251022 rows x 2 columns]

# %%
# Agregamos una columna con la etiqueta de los clusters. K = 2
mca_coordinates['cluster_labels'] = df_FCluster2['cluster_labels']
mca_coordinates
# Out:
#                 0         1  cluster_labels
# 793619   0.259742 -0.069923               1
# 366899   0.035148  0.111118               0
# 689408  -0.001708  0.084789               0
# 474680  -0.049146  0.055196               0
# 944418  -0.042757  0.063742               0
# ...           ...       ...             ...
# 1681168 -0.100004  0.077715               0
# 1138052 -0.064292  0.175291               0
# 1647239 -0.114174 -0.144791               0
# 1711899 -0.015799  0.029335               0
# 1956942 -0.069102  0.108258               0
#
# [251022 rows x 3 columns]

# %%
# Dibujamos los clusters
import seaborn as sns
import matplotlib.pyplot as plt

# Dibuja el diagrama de dispersión coloreando los puntos por grupo.

sns.scatterplot(data=mca_coordinates, x=mca_coordinates.iloc[:, 0], y=mca_coordinates.iloc[:, 1], hue='cluster_labels')

# Agregar una leyenda
plt.legend(title='Cluster')

# Optional: Add title and axis labels
plt.title('Cluster Visualization')
plt.xlabel('MCA0')
plt.ylabel('MCA1')

# Show the plot
plt.show()

# %% [markdown]
# # Observaciones clase 06 de mayo
# ## Los comentarios y sugerencias de los profesores sobre la entrega actual dejan varias tareas para la ocasión:
# * ### Cambiar random_state para que concuerde con el número del equipo
# * ### Modificar, optimizar y probar hiperparámetros según lo mostrado en la misma clase
# * ### Seleccionar variables
# * * #### Para este caso se probará primero con los dataframes obtenidos para los clusters: df_FCluster2 y df_FCluster3

# %% [markdown]
# En primer lugar, random_state se cambió a 4 en una de las celdas de inicio para que la aleatoriedad de la muestra sea el número del equipo

# %% [markdown]
# Se volverá a calcular Average Categorical Silhouette Score para los dataframes con 2 y 3 clusters, modificando y añadiendo hiperparámeros hasta llegar a un mínimo de 0.2
#
# Siguiendo la recomendación del profesor Henry, no se modificarán los hiperparámetros de max_iter y cat_dissim

# %% [markdown]
# Para reducir el tiempo de cada prueba, KModes usará todos los procesadores disponibles con el hiperparámetro n_jobs=-1

# %% [markdown]
# Se aumentará únicamente n_init a 20

# %% [markdown]
# ### Para K = 2

# %%
n_clusters_tst = 2
km_tst = KModes(n_clusters=n_clusters_tst, init='Huang', n_init=20, n_jobs=-1 ,verbose=1)
clusters_2_tst = km_tst.fit_predict(df_Final)
clusters_2_tst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 n_clusters_tst = 2
# ----> 2 km_tst = KModes(n_clusters=n_clusters_tst, init='Huang', n_init=20, n_jobs=-1 ,verbose=1)
#       3 clusters_2_tst = km_tst.fit_predict(df_Final)
#       4 clusters_2_tst
#
# NameError: name 'KModes' is not defined

# %%
# Insertemos las etiquetas en nuestro dataset.
df_FCluster2_tst = df_Final.copy()
df_FCluster2_tst.insert(7,"cluster_labels", clusters_2_tst)
df_FCluster2_tst
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               0
# 366899                          Bolívar    Urbana               1
# 689408                        Pichincha    Urbana               1
# 474680                           Guayas    Urbana               1
# 944418                           Guayas    Urbana               0
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               1
# 1138052                          Manabí    Urbana               1
# 1647239                          Guayas    Urbana               0
# 1711899                          Guayas    Urbana               1
# 1956942                          Carchi    Urbana               1
#
# [251022 rows x 8 columns]

# %%
#Muestra
df_str_tst = df_FCluster2_tst.sample(n=5000, random_state=1)

# %%
# Calcular la matriz de distancias de Gower
gower_distances_tst = gower.gower_matrix(df_str_tst.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower_tst = silhouette_score(gower_distances_tst, df_str_tst['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 2:", silhouette_avg_gower_tst)
# Out:
# Average Categorical Silhouette Score con K = 2: 0.1320804

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\todolaps\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\todolaps\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\todolaps\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\todolaps\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 393.8 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 363.1 kB/s eta 0:00:01
#    ---------- ---------------------------- 81.9/294.9 kB 416.7 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 348.6 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.9 kB 385.0 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/294.9 kB 359.9 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 387.0 kB/s eta 0:00:01
#    --------------------- ---------------- 163.8/294.9 kB 364.0 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.9 kB 380.0 kB/s eta 0:00:01
#    -------------------------- ----------- 204.8/294.9 kB 377.1 kB/s eta 0:00:01
#    --------------------------- ---------- 215.0/294.9 kB 344.8 kB/s eta 0:00:01
#    ------------------------------- ------ 245.8/294.9 kB 367.4 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/294.9 kB 365.7 kB/s eta 0:00:01
#    ----------------------------------- -- 276.5/294.9 kB 378.7 kB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 357.2 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))
sns.barplot(data=df_FCluster2_tst, x='Dificultad', y='Probabilidad', hue='IQ')
plt.title('Probabilidad de Admisión por Dificultad e IQ')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 import pandas as pd
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.barplot(data=df_FCluster2_tst, x='Dificultad', y='Probabilidad', hue='IQ')
#       7 plt.title('Probabilidad de Admisión por Dificultad e IQ')
#       8 plt.show()
#
# NameError: name 'df_FCluster2_tst' is not defined

# %% [markdown]
# El ACSS bajó ligeramente, se intentará añadir un valor aleatorio de inicialización

# %%
n_clusters_tst = 2
km_tst = KModes(n_clusters=n_clusters_tst, init='Huang', n_init=20, n_jobs=-1, verbose=1, random_state=1)
clusters_2_tst = km_tst.fit_predict(df_Final)
clusters_2_tst
# Out:
# Best run was number 9
# array([0, 1, 1, ..., 0, 1, 1], dtype=uint16)

# %%
# Insertemos las etiquetas en nuestro dataset.
df_FCluster2_tst = df_Final.copy()
df_FCluster2_tst.insert(7,"cluster_labels", clusters_2_tst)
df_FCluster2_tst
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               0
# 366899                          Bolívar    Urbana               1
# 689408                        Pichincha    Urbana               1
# 474680                           Guayas    Urbana               1
# 944418                           Guayas    Urbana               1
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               1
# 1138052                          Manabí    Urbana               1
# 1647239                          Guayas    Urbana               0
# 1711899                          Guayas    Urbana               1
# 1956942                          Carchi    Urbana               1
#
# [251022 rows x 8 columns]

# %% [markdown]
# Adicionalmente, se cambió el random_state de la muestra del dataframe, únicamente para probar si esto cambiaba en algo el ACSS

# %%
#Muestra
df_str_tst = df_FCluster2_tst.sample(n=5000, random_state=4)

# %%
# Calcular la matriz de distancias de Gower
gower_distances_tst = gower.gower_matrix(df_str_tst.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower_tst = silhouette_score(gower_distances_tst, df_str_tst['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 2:", silhouette_avg_gower_tst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       2 gower_distances_tst = gower.gower_matrix(df_str_tst.drop('cluster_labels', axis=1))
#       3 # Calcular el Silhouette Score
# ----> 4 silhouette_avg_gower_tst = silhouette_score(gower_distances, df_str_tst['cluster_labels'], metric='precomputed')
#       5 print("Average Categorical Silhouette Score con K = 2:", silhouette_avg_gower_tst)
#
# File c:\Users\crisb\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:117, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115     else:
#     116         X, labels = X[indices], labels[indices]
# --> 117 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File c:\Users\crisb\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:212, in silhouette_samples(X, labels, metric, **kwds)
#     152 def silhouette_samples(X, labels, *, metric="euclidean", **kwds):
#     153     """Compute the Silhouette Coefficient for each sample.
#     154
#     155     The Silhouette Coefficient is a measure of how well samples are clustered
#    (...)
#     210        <https://en.wikipedia.org/wiki/Silhouette_(clustering)>`_
#     211     """
# --> 212     X, labels = check_X_y(X, labels, accept_sparse=["csc", "csr"])
#     214     # Check for non-zero diagonal entries in precomputed distance matrix
#     215     if metric == "precomputed":
#
# File c:\Users\crisb\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1124, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    (...)
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1124 check_consistent_length(X, y)
#    1126 return X, y
#
# File c:\Users\crisb\anaconda3\Lib\site-packages\sklearn\utils\validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [20000, 5000]

# %% [markdown]
# ### Para K = 3

# %%
n_clusters_tst = 3
km_tst = KModes(n_clusters=n_clusters_tst, init='Huang', n_init=20, n_jobs=-1, verbose=1)
clusters_3_tst = km_tst.fit_predict(df_Final)
clusters_3_tst
# Out:
# Best run was number 14
# array([1, 0, 0, ..., 1, 2, 0], dtype=uint16)

# %%
# Insertemos las etiquetas en nuestro dataset original.
df_FCluster3_tst = df_Final.copy()
df_FCluster3_tst.insert(7,"cluster_labels", clusters_3_tst)
df_FCluster3_tst
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               1
# 366899                          Bolívar    Urbana               0
# 689408                        Pichincha    Urbana               0
# 474680                           Guayas    Urbana               2
# 944418                           Guayas    Urbana               2
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               0
# 1138052                          Manabí    Urbana               2
# 1647239                          Guayas    Urbana               1
# 1711899                          Guayas    Urbana               2
# 1956942                          Carchi    Urbana               0
#
# [251022 rows x 8 columns]

# %%
#Muestra de nuevo
df_str_tst = df_FCluster3_tst.sample(n=5000, random_state=1)

# %%
# Luego calcular la matriz de distancias de Gower como antes
gower_distances_tst = gower.gower_matrix(df_str_tst.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower_tst = silhouette_score(gower_distances_tst, df_str_tst['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 3:", silhouette_avg_gower_tst)

# %% [markdown]
# El ACSS bajó ligeramente, se intentará añadir un valor aleatorio de inicialización

# %% [markdown]
# ACSS aumentó ligeramente, se

# %%
n_clusters_tst = 2
km_tst = KModes(n_clusters=n_clusters_tst, init='Huang', n_init=20, n_jobs=-1, verbose=1, random_state=5)
clusters_2_tst = km_tst.fit_predict(df_Final)
clusters_2_tst
# Out:
# Best run was number 8
# array([1, 0, 0, ..., 1, 0, 0], dtype=uint16)

# %%
# Insertemos las etiquetas en nuestro dataset.
df_FCluster2_tst = df_Final.copy()
df_FCluster2_tst.insert(7,"cluster_labels", clusters_2_tst)
df_FCluster2_tst
# Out:
#            sexo anio_fall    mes_fall  edad  \
# 793619    Mujer    2004.0   Noviembre  74.0
# 366899   Hombre    1997.0  Septiembre  25.0
# 689408   Hombre    2002.0   Noviembre  16.0
# 474680   Hombre    1999.0       Marzo   3.0
# 944418   Hombre    2007.0       Abril  47.0
# ...         ...       ...         ...   ...
# 1681168  Hombre    2018.0   Diciembre  76.0
# 1138052  Hombre    2010.0   Diciembre  39.0
# 1647239   Mujer    2018.0   Diciembre  84.0
# 1711899  Hombre    2019.0        Mayo  89.0
# 1956942  Hombre    2021.0        Mayo  35.0
#
#                                             lugar_ocur  \
# 793619                                            Casa
# 366899                                            Casa
# 689408                                            Casa
# 474680                                            Casa
# 944418                                            Casa
# ...                                                ...
# 1681168                      Establecimientos del IESS
# 1138052                                           Otro
# 1647239  Establecimientos de la Junta de Beneficiencia
# 1711899                                           Casa
# 1956942        Establecimiento del Ministerio de Salud
#
#                               prov_fall area_fall  cluster_labels
# 793619                        Pichincha     Rural               1
# 366899                          Bolívar    Urbana               0
# 689408                        Pichincha    Urbana               0
# 474680                           Guayas    Urbana               0
# 944418                           Guayas    Urbana               0
# ...                                 ...       ...             ...
# 1681168  Santo Domingo de los Tsachilas    Urbana               0
# 1138052                          Manabí    Urbana               0
# 1647239                          Guayas    Urbana               1
# 1711899                          Guayas    Urbana               0
# 1956942                          Carchi    Urbana               0
#
# [251022 rows x 8 columns]

# %%
#Muestra
df_str_tst = df_FCluster2_tst.sample(n=5000, random_state=4)

# %%
# Calcular la matriz de distancias de Gower
gower_distances = gower.gower_matrix(df_str_tst.drop('cluster_labels', axis=1))
# Calcular el Silhouette Score
silhouette_avg_gower_tst = silhouette_score(gower_distances, df_str_tst['cluster_labels'], metric='precomputed')
print("Average Categorical Silhouette Score con K = 2:", silhouette_avg_gower_tst)
# Out:
# Average Categorical Silhouette Score con K = 2: 0.17204906
